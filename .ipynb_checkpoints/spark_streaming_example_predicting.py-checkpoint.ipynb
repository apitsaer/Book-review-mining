# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))
# Out:
# <style>.container { width:95% !important; }</style>

# %%
sc
# Out:
# <SparkContext master=local[*] appName=PySparkShell>

# %%
from threading import Thread

class StreamingThread(Thread):
    def __init__(self, ssc):
        Thread.__init__(self)
        self.ssc = ssc
    def run(self):
        ssc.start()
        ssc.awaitTermination()
    def stop(self):
        print('----- Stopping... this may take a few seconds -----')
        self.ssc.stop(stopSparkContext=False, stopGraceFully=True)

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://10.45.217.2:4044">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v2.4.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>PySparkShell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
from pyspark.streaming import StreamingContext
from pyspark.sql import Row
from pyspark.sql.functions import udf, struct
from pyspark.sql.types import IntegerType
from pyspark.ml import PipelineModel
from pyspark.sql import functions as fn

# %%
globals()['models_loaded'] = False

path = "lrm_bin.model"

def predict(df):
    # Replace this with something smarter
    
    #print('models_loaded: ' + str(models_loaded))
    
    if any([x in df.review_text for x in ['not', 'bad', 'terrible', 'zero', 'one']]):
        return 0
    return 0

predict_udf = udf(predict, IntegerType())

def process(time, rdd):
    if rdd.isEmpty():
        return
    print("========= %s =========" % str(time))
    
    # Convert to data frame
    df_original = spark.read.json(rdd)
    df_with_concat = df_original.withColumn('review_concat',fn.concat(fn.col('review_title'),fn.lit(' '), fn.col('review_text')))
    df_original_light = df_with_concat.select('review_score', 'review_concat')
    #df_original_light.show()
    
    # Utilize our predict function
    #df_withpreds = df_light.withColumn("pred", predict_udf(struct([df_with_concat[x] for x in df_with_concat.columns])))

    #df_withpreds = df_with_concat.withColumn("pred", predict_udf(struct([df_with_concat[x] for x in df_with_concat.columns])))
    #df_withpreds.show()
    #print('df size + ' + str(df_withpreds.count()))

    # In this case, you need to prevent loading your model in every call to "process" as follows:
    # Load in the model if not yet loaded:
    if not globals()['models_loaded']:
        # load in your models here
        #globals()['my_model'] = 'my_model' # Replace this with:    [...].load('my_logistic_regression')
        globals()['my_model'] = PipelineModel.load(path)
        globals()['models_loaded'] = True
        print('****** Model loaded ******')  
        
    # Predict using the model: 
    df_result = globals()['my_model'].transform(df_with_concat)
    df_result_light = df_result.select('book_title', 'review_concat', 'review_score', 'prediction')
    df_result_light.show()

# %%
ssc = StreamingContext(sc, 10)

# %%
lines = ssc.socketTextStream("seppe.net", 7778)
lines.foreachRDD(process)

# %%
ssc_t = StreamingThread(ssc)
ssc_t.start()
print('****** Starting prediction ******')
print('  - Prediction = 0 means bad review (score 1 or 2)')
print('  - Prediction = 1 means good review (score 3 to 5) \n')
# Out:
# ****** Starting prediction ******
#   - Prediction = 0 means bad review (score 1 or 2)
#   - Prediction = 1 means good review (score 3 to 5)
#
# ========= 2019-05-23 14:13:00 =========
# ****** Model loaded ******
# +--------------------+--------------------+------------+----------+
# |          book_title|       review_concat|review_score|prediction|
# +--------------------+--------------------+------------+----------+
# |The Great Alone: ...|Well written fami...|           4|       1.0|
# +--------------------+--------------------+------------+----------+
#
# ========= 2019-05-23 14:13:10 =========
# +--------------------+--------------------+------------+----------+
# |          book_title|       review_concat|review_score|prediction|
# +--------------------+--------------------+------------+----------+
# |Sunset Beach: A N...|Sunset Beach Grea...|           4|       1.0|
# +--------------------+--------------------+------------+----------+
#
# ========= 2019-05-23 14:13:50 =========
# +--------------------+--------------------+------------+----------+
# |          book_title|       review_concat|review_score|prediction|
# +--------------------+--------------------+------------+----------+
# |QAnon: An Invitat...|Junk A piece of l...|           1|       0.0|
# +--------------------+--------------------+------------+----------+
#
# ========= 2019-05-23 14:14:40 =========
# +--------------------+--------------------+------------+----------+
# |          book_title|       review_concat|review_score|prediction|
# +--------------------+--------------------+------------+----------+
# |All the Way: My L...|different read di...|           5|       1.0|
# +--------------------+--------------------+------------+----------+
#
# ========= 2019-05-23 14:16:00 =========
# +--------------------+--------------------+------------+----------+
# |          book_title|       review_concat|review_score|prediction|
# +--------------------+--------------------+------------+----------+
# |The Great Alone: ...|Well written fami...|           4|       1.0|
# +--------------------+--------------------+------------+----------+
#
# ========= 2019-05-23 14:17:30 =========
# +--------------------+--------------------+------------+----------+
# |          book_title|       review_concat|review_score|prediction|
# +--------------------+--------------------+------------+----------+
# |The 18th Abductio...|The 18th Abductio...|           4|       1.0|
# +--------------------+--------------------+------------+----------+
#
# ========= 2019-05-23 14:20:30 =========
# +--------------------+--------------------+------------+----------+
# |          book_title|       review_concat|review_score|prediction|
# +--------------------+--------------------+------------+----------+
# |Sunset Beach: A N...|Sunset Beach Grea...|           4|       1.0|
# +--------------------+--------------------+------------+----------+
#
# ========= 2019-05-23 14:21:00 =========
# +--------------------+--------------------+------------+----------+
# |          book_title|       review_concat|review_score|prediction|
# +--------------------+--------------------+------------+----------+
# |All the Way: My L...|different read di...|           5|       1.0|
# +--------------------+--------------------+------------+----------+
#
# ========= 2019-05-23 14:21:30 =========
# +--------------------+--------------------+------------+----------+
# |          book_title|       review_concat|review_score|prediction|
# +--------------------+--------------------+------------+----------+
# |The Woman in the ...|Book club read Gr...|           5|       1.0|
# +--------------------+--------------------+------------+----------+
#
# ========= 2019-05-23 14:22:00 =========
# +--------------------+--------------------+------------+----------+
# |          book_title|       review_concat|review_score|prediction|
# +--------------------+--------------------+------------+----------+
# |The Great Alone: ...|Well written fami...|           4|       1.0|
# +--------------------+--------------------+------------+----------+
#
# ========= 2019-05-23 14:26:40 =========
# +--------------------+--------------------+------------+----------+
# |          book_title|       review_concat|review_score|prediction|
# +--------------------+--------------------+------------+----------+
# |The 18th Abductio...|The 18th Abductio...|           4|       1.0|
# +--------------------+--------------------+------------+----------+
#
# ========= 2019-05-23 14:27:20 =========
# +--------------------+--------------------+------------+----------+
# |          book_title|       review_concat|review_score|prediction|
# +--------------------+--------------------+------------+----------+
# |QAnon: An Invitat...|Great Read Great ...|           5|       1.0|
# +--------------------+--------------------+------------+----------+
#
# ========= 2019-05-23 14:30:30 =========
# +--------------------+--------------------+------------+----------+
# |          book_title|       review_concat|review_score|prediction|
# +--------------------+--------------------+------------+----------+
# |Pet Sematary: A N...|A real page-turne...|           1|       1.0|
# +--------------------+--------------------+------------+----------+
#
# ========= 2019-05-23 14:36:20 =========
# +--------------------+--------------------+------------+----------+
# |          book_title|       review_concat|review_score|prediction|
# +--------------------+--------------------+------------+----------+
# |Sunset Beach: A N...|Sunset Beach Grea...|           4|       1.0|
# +--------------------+--------------------+------------+----------+
#
# ========= 2019-05-23 14:37:40 =========
# +--------------------+--------------------+------------+----------+
# |          book_title|       review_concat|review_score|prediction|
# +--------------------+--------------------+------------+----------+
# |The Woman in the ...|The Woman in the ...|           5|       1.0|
# +--------------------+--------------------+------------+----------+
#
# ========= 2019-05-23 14:40:20 =========
# +--------------------+--------------------+------------+----------+
# |          book_title|       review_concat|review_score|prediction|
# +--------------------+--------------------+------------+----------+
# |The Great Alone: ...|Well written fami...|           4|       1.0|
# +--------------------+--------------------+------------+----------+
#
# ========= 2019-05-23 14:42:40 =========
# +--------------------+--------------------+------------+----------+
# |          book_title|       review_concat|review_score|prediction|
# +--------------------+--------------------+------------+----------+
# |The 18th Abductio...|The 18th Abductio...|           4|       1.0|
# +--------------------+--------------------+------------+----------+
#
# ========= 2019-05-23 14:43:50 =========
# +--------------------+--------------------+------------+----------+
# |          book_title|       review_concat|review_score|prediction|
# +--------------------+--------------------+------------+----------+
# |The Great Alone: ...|Well written fami...|           4|       1.0|
# +--------------------+--------------------+------------+----------+
#
# ========= 2019-05-23 14:44:30 =========
# +--------------------+--------------------+------------+----------+
# |          book_title|       review_concat|review_score|prediction|
# +--------------------+--------------------+------------+----------+
# |Sunset Beach: A N...|Sunset Beach Grea...|           4|       1.0|
# +--------------------+--------------------+------------+----------+
#
# ========= 2019-05-23 14:50:40 =========
# +--------------------+--------------------+------------+----------+
# |          book_title|       review_concat|review_score|prediction|
# +--------------------+--------------------+------------+----------+
# |The Woman in the ...|Pretty good first...|           4|       1.0|
# +--------------------+--------------------+------------+----------+
#
# ========= 2019-05-23 14:51:40 =========
# +--------------------+--------------------+------------+----------+
# |          book_title|       review_concat|review_score|prediction|
# +--------------------+--------------------+------------+----------+
# |After (The After ...|When I say it is ...|           5|       1.0|
# +--------------------+--------------------+------------+----------+
#
# ========= 2019-05-23 14:54:30 =========
# +--------------------+--------------------+------------+----------+
# |          book_title|       review_concat|review_score|prediction|
# +--------------------+--------------------+------------+----------+
# |The Great Alone: ...|Well written fami...|           4|       1.0|
# +--------------------+--------------------+------------+----------+
#
# ========= 2019-05-23 14:58:30 =========
# +--------------------+--------------------+------------+----------+
# |          book_title|       review_concat|review_score|prediction|
# +--------------------+--------------------+------------+----------+
# |Sunset Beach: A N...|Sunset Beach Grea...|           4|       1.0|
# +--------------------+--------------------+------------+----------+
#
# ========= 2019-05-23 15:00:30 =========
# +--------------------+--------------------+------------+----------+
# |          book_title|       review_concat|review_score|prediction|
# +--------------------+--------------------+------------+----------+
# |Sunset Beach: A N...|Sunset Beach Grea...|           4|       1.0|
# +--------------------+--------------------+------------+----------+
#
# ========= 2019-05-23 15:02:50 =========
# +--------------------+--------------------+------------+----------+
# |          book_title|       review_concat|review_score|prediction|
# +--------------------+--------------------+------------+----------+
# |The 18th Abductio...|2 thi Very dark a...|           4|       1.0|
# +--------------------+--------------------+------------+----------+
#
# ========= 2019-05-23 15:04:40 =========
# +--------------------+--------------------+------------+----------+
# |          book_title|       review_concat|review_score|prediction|
# +--------------------+--------------------+------------+----------+
# |The Great Alone: ...|Well written fami...|           4|       1.0|
# +--------------------+--------------------+------------+----------+
#
# ========= 2019-05-23 15:06:30 =========
# +--------------------+--------------------+------------+----------+
# |          book_title|       review_concat|review_score|prediction|
# +--------------------+--------------------+------------+----------+
# |The 18th Abductio...|2 thi Very dark a...|           4|       1.0|
# +--------------------+--------------------+------------+----------+
#
# ========= 2019-05-23 15:08:20 =========
# +--------------------+--------------------+------------+----------+
# |          book_title|       review_concat|review_score|prediction|
# +--------------------+--------------------+------------+----------+
# |Full Count: The E...|Perfect! Bought a...|           5|       1.0|
# +--------------------+--------------------+------------+----------+
#
# ========= 2019-05-23 15:10:40 =========
# +--------------------+--------------------+------------+----------+
# |          book_title|       review_concat|review_score|prediction|
# +--------------------+--------------------+------------+----------+
# |Go See the Princi...|Elitist and entit...|           4|       0.0|
# +--------------------+--------------------+------------+----------+
#
# ========= 2019-05-23 15:15:00 =========
# +--------------------+--------------------+------------+----------+
# |          book_title|       review_concat|review_score|prediction|
# +--------------------+--------------------+------------+----------+
# |The Great Alone: ...|Well written fami...|           4|       1.0|
# +--------------------+--------------------+------------+----------+
#
# ========= 2019-05-23 15:15:40 =========
# +--------------------+--------------------+------------+----------+
# |          book_title|       review_concat|review_score|prediction|
# +--------------------+--------------------+------------+----------+
# |Full Count: The E...|Perfect! Bought a...|           5|       1.0|
# +--------------------+--------------------+------------+----------+
#
# ========= 2019-05-23 15:16:00 =========
# +--------------------+--------------------+------------+----------+
# |          book_title|       review_concat|review_score|prediction|
# +--------------------+--------------------+------------+----------+
# |Cat and Nat's Mom...|Must read! Amazin...|           5|       1.0|
# +--------------------+--------------------+------------+----------+
#
# ========= 2019-05-23 15:16:20 =========
# +--------------------+--------------------+------------+----------+
# |          book_title|       review_concat|review_score|prediction|
# +--------------------+--------------------+------------+----------+
# |The Woman in the ...|Such a great book...|           5|       1.0|
# +--------------------+--------------------+------------+----------+
#
# ========= 2019-05-23 15:19:00 =========
# +--------------------+--------------------+------------+----------+
# |          book_title|       review_concat|review_score|prediction|
# +--------------------+--------------------+------------+----------+
# |The Great Alone: ...|Well written fami...|           4|       1.0|
# +--------------------+--------------------+------------+----------+
#
# ========= 2019-05-23 15:20:20 =========
# +--------------------+--------------------+------------+----------+
# |          book_title|       review_concat|review_score|prediction|
# +--------------------+--------------------+------------+----------+
# |The Great Alone: ...|Well written fami...|           4|       1.0|
# +--------------------+--------------------+------------+----------+
#
# ========= 2019-05-23 15:20:30 =========
# +--------------------+--------------------+------------+----------+
# |          book_title|       review_concat|review_score|prediction|
# +--------------------+--------------------+------------+----------+
# |Go See the Princi...|Elitist and entit...|           4|       0.0|
# +--------------------+--------------------+------------+----------+
#
# ========= 2019-05-23 15:24:10 =========
# +--------------------+--------------------+------------+----------+
# |          book_title|       review_concat|review_score|prediction|
# +--------------------+--------------------+------------+----------+
# |The Great Alone: ...|I recommend this ...|           4|       1.0|
# +--------------------+--------------------+------------+----------+
#
# ========= 2019-05-23 15:25:40 =========
# +--------------------+--------------------+------------+----------+
# |          book_title|       review_concat|review_score|prediction|
# +--------------------+--------------------+------------+----------+
# |Full Count: The E...|Perfect! Bought a...|           5|       1.0|
# +--------------------+--------------------+------------+----------+
#
# ========= 2019-05-23 15:25:50 =========
# +--------------------+--------------------+------------+----------+
# |          book_title|       review_concat|review_score|prediction|
# +--------------------+--------------------+------------+----------+
# |Go See the Princi...|Elitist and entit...|           4|       0.0|
# |The 18th Abductio...|2 thi Very dark a...|           4|       1.0|
# +--------------------+--------------------+------------+----------+
#
# ========= 2019-05-23 15:31:00 =========
# +--------------------+--------------------+------------+----------+
# |          book_title|       review_concat|review_score|prediction|
# +--------------------+--------------------+------------+----------+
# |After (The After ...|It was OK I love ...|           2|       1.0|
# +--------------------+--------------------+------------+----------+
#
# ========= 2019-05-23 15:31:30 =========
# +--------------------+--------------------+------------+----------+
# |          book_title|       review_concat|review_score|prediction|
# +--------------------+--------------------+------------+----------+
# |Full Count: The E...|Perfect! Bought a...|           5|       1.0|
# +--------------------+--------------------+------------+----------+
#
# ========= 2019-05-23 15:32:20 =========
# +--------------------+--------------------+------------+----------+
# |          book_title|       review_concat|review_score|prediction|
# +--------------------+--------------------+------------+----------+
# |Go See the Princi...|Elitist and entit...|           4|       0.0|
# +--------------------+--------------------+------------+----------+
#
# ========= 2019-05-23 15:34:40 =========
# +--------------------+--------------------+------------+----------+
# |          book_title|       review_concat|review_score|prediction|
# +--------------------+--------------------+------------+----------+
# |The 18th Abductio...|2 thi Very dark a...|           4|       1.0|
# +--------------------+--------------------+------------+----------+
# ========= 2019-05-23 15:36:00 =========
# +--------------------+--------------------+------------+----------+
# |          book_title|       review_concat|review_score|prediction|
# +--------------------+--------------------+------------+----------+
# |The Great Alone: ...|I recommend this ...|           4|       1.0|
# +--------------------+--------------------+------------+----------+
#
# ========= 2019-05-23 15:37:30 =========
# +--------------------+--------------------+------------+----------+
# |          book_title|       review_concat|review_score|prediction|
# +--------------------+--------------------+------------+----------+
# |The 18th Abductio...|2 thi Very dark a...|           4|       1.0|
# +--------------------+--------------------+------------+----------+
#
# ========= 2019-05-23 15:39:30 =========
# +--------------------+--------------------+------------+----------+
# |          book_title|       review_concat|review_score|prediction|
# +--------------------+--------------------+------------+----------+
# |Full Count: The E...|Perfect! Bought a...|           5|       1.0|
# +--------------------+--------------------+------------+----------+
#
# ========= 2019-05-23 15:42:40 =========
# +--------------------+--------------------+------------+----------+
# |          book_title|       review_concat|review_score|prediction|
# +--------------------+--------------------+------------+----------+
# |The 18th Abductio...|2 thi Very dark a...|           4|       1.0|
# +--------------------+--------------------+------------+----------+
#
# ========= 2019-05-23 15:42:50 =========
# +--------------------+--------------------+------------+----------+
# |          book_title|       review_concat|review_score|prediction|
# +--------------------+--------------------+------------+----------+
# |The Great Alone: ...|I recommend this ...|           4|       1.0|
# +--------------------+--------------------+------------+----------+
#
# ========= 2019-05-23 15:47:50 =========
# +--------------------+--------------------+------------+----------+
# |          book_title|       review_concat|review_score|prediction|
# +--------------------+--------------------+------------+----------+
# |Food of the Itali...|Wonderful! Food o...|           5|       1.0|
# +--------------------+--------------------+------------+----------+
#
# ========= 2019-05-23 15:50:30 =========
# +--------------------+--------------------+------------+----------+
# |          book_title|       review_concat|review_score|prediction|
# +--------------------+--------------------+------------+----------+
# |Go See the Princi...|Elitist and entit...|           4|       0.0|
# +--------------------+--------------------+------------+----------+
#
# ========= 2019-05-23 15:50:40 =========
# +--------------------+--------------------+------------+----------+
# |          book_title|       review_concat|review_score|prediction|
# +--------------------+--------------------+------------+----------+
# |The 18th Abductio...|2 thi Very dark a...|           4|       1.0|
# +--------------------+--------------------+------------+----------+
#
# ========= 2019-05-23 15:51:30 =========
# +--------------------+--------------------+------------+----------+
# |          book_title|       review_concat|review_score|prediction|
# +--------------------+--------------------+------------+----------+
# |The Great Alone: ...|I recommend this ...|           4|       1.0|
# +--------------------+--------------------+------------+----------+
#
# ========= 2019-05-23 15:51:40 =========
# +--------------------+--------------------+------------+----------+
# |          book_title|       review_concat|review_score|prediction|
# +--------------------+--------------------+------------+----------+
# |Full Count: The E...|Perfect! Bought a...|           5|       1.0|
# +--------------------+--------------------+------------+----------+
#
# ========= 2019-05-23 15:52:50 =========
# +--------------------+--------------------+------------+----------+
# |          book_title|       review_concat|review_score|prediction|
# +--------------------+--------------------+------------+----------+
# |Discrimination an...|Great book What I...|           5|       1.0|
# +--------------------+--------------------+------------+----------+
#
# ========= 2019-05-23 15:56:20 =========
# +--------------------+--------------------+------------+----------+
# |          book_title|       review_concat|review_score|prediction|
# +--------------------+--------------------+------------+----------+
# |The Great Alone: ...|I recommend this ...|           4|       1.0|
# +--------------------+--------------------+------------+----------+
#
# ========= 2019-05-23 15:59:20 =========
# +--------------------+--------------------+------------+----------+
# |          book_title|       review_concat|review_score|prediction|
# +--------------------+--------------------+------------+----------+
# |The Great Alone: ...|I recommend this ...|           4|       1.0|
# +--------------------+--------------------+------------+----------+
#
# ========= 2019-05-23 15:59:30 =========
# +--------------------+--------------------+------------+----------+
# |          book_title|       review_concat|review_score|prediction|
# +--------------------+--------------------+------------+----------+
# |The Border: A Nov...|Tough, important ...|           5|       1.0|
# +--------------------+--------------------+------------+----------+
#
# ========= 2019-05-23 16:00:40 =========
# +--------------------+--------------------+------------+----------+
# |          book_title|       review_concat|review_score|prediction|
# +--------------------+--------------------+------------+----------+
# |The 18th Abductio...|2 thi Very dark a...|           4|       1.0|
# +--------------------+--------------------+------------+----------+
#
# ========= 2019-05-23 16:06:00 =========
# +--------------------+--------------------+------------+----------+
# |          book_title|       review_concat|review_score|prediction|
# +--------------------+--------------------+------------+----------+
# |The Great Alone: ...|I recommend this ...|           4|       1.0|
# +--------------------+--------------------+------------+----------+
#
# ========= 2019-05-23 16:07:00 =========
# +--------------------+--------------------+------------+----------+
# |          book_title|       review_concat|review_score|prediction|
# +--------------------+--------------------+------------+----------+
# |The Great Alone: ...|I recommend this ...|           4|       1.0|
# +--------------------+--------------------+------------+----------+
#
# ========= 2019-05-23 16:10:30 =========
# +--------------------+---------------+------------+----------+
# |          book_title|  review_concat|review_score|prediction|
# +--------------------+---------------+------------+----------+
# |Pet Sematary: A N...|Amazing Love it|           5|       1.0|
# +--------------------+---------------+------------+----------+
#
# ========= 2019-05-23 16:12:30 =========
# +--------------------+--------------------+------------+----------+
# |          book_title|       review_concat|review_score|prediction|
# +--------------------+--------------------+------------+----------+
# |The 18th Abductio...|2 thi Very dark a...|           4|       1.0|
# +--------------------+--------------------+------------+----------+
#
# ========= 2019-05-23 16:13:00 =========
# +--------------------+--------------------+------------+----------+
# |          book_title|       review_concat|review_score|prediction|
# +--------------------+--------------------+------------+----------+
# |Spying on the Sou...|Tony Horwitz cont...|           5|       1.0|
# +--------------------+--------------------+------------+----------+
#
# ========= 2019-05-23 16:15:20 =========
# +--------------------+--------------------+------------+----------+
# |          book_title|       review_concat|review_score|prediction|
# +--------------------+--------------------+------------+----------+
# |The Rational Bibl...|Rational Bible I ...|           5|       0.0|
# +--------------------+--------------------+------------+----------+
#
# ========= 2019-05-23 16:16:00 =========
# +--------------------+--------------------+------------+----------+
# |          book_title|       review_concat|review_score|prediction|
# +--------------------+--------------------+------------+----------+
# |Spying on the Sou...|Tony Horwitz cont...|           5|       1.0|
# +--------------------+--------------------+------------+----------+
# ========= 2019-05-23 16:17:40 =========
# +--------------------+--------------------+------------+----------+
# |          book_title|       review_concat|review_score|prediction|
# +--------------------+--------------------+------------+----------+
# |Spying on the Sou...|Tony Horwitz cont...|           5|       1.0|
# +--------------------+--------------------+------------+----------+
#
# ========= 2019-05-23 16:20:00 =========
# +--------------------+--------------------+------------+----------+
# |          book_title|       review_concat|review_score|prediction|
# +--------------------+--------------------+------------+----------+
# |The Great Alone: ...|I recommend this ...|           4|       1.0|
# +--------------------+--------------------+------------+----------+
#
# ========= 2019-05-23 16:25:40 =========
# +--------------------+--------------------+------------+----------+
# |          book_title|       review_concat|review_score|prediction|
# +--------------------+--------------------+------------+----------+
# |The 18th Abductio...|2 thi Very dark a...|           4|       1.0|
# +--------------------+--------------------+------------+----------+
#
# ========= 2019-05-23 16:26:10 =========
# +--------------------+--------------------+------------+----------+
# |          book_title|       review_concat|review_score|prediction|
# +--------------------+--------------------+------------+----------+
# |The Rational Bibl...|Rational Bible I ...|           5|       0.0|
# +--------------------+--------------------+------------+----------+
#
# ========= 2019-05-23 16:27:20 =========
# +--------------------+--------------------+------------+----------+
# |          book_title|       review_concat|review_score|prediction|
# +--------------------+--------------------+------------+----------+
# |The Woman in the ...|First great thril...|           5|       1.0|
# +--------------------+--------------------+------------+----------+
#
# ========= 2019-05-23 16:28:50 =========
# +--------------------+--------------------+------------+----------+
# |          book_title|       review_concat|review_score|prediction|
# +--------------------+--------------------+------------+----------+
# |The Woman in the ...|Awesome debut nov...|           4|       1.0|
# +--------------------+--------------------+------------+----------+
#
# ========= 2019-05-23 16:29:40 =========
# +--------------------+--------------------+------------+----------+
# |          book_title|       review_concat|review_score|prediction|
# +--------------------+--------------------+------------+----------+
# |The Great Alone: ...|I recommend this ...|           4|       1.0|
# +--------------------+--------------------+------------+----------+
#
# ========= 2019-05-23 16:35:30 =========
# +--------------------+--------------------+------------+----------+
# |          book_title|       review_concat|review_score|prediction|
# +--------------------+--------------------+------------+----------+
# |The 18th Abductio...|Another great sto...|           4|       1.0|
# |Spying on the Sou...|Tony Horwitz cont...|           5|       1.0|
# +--------------------+--------------------+------------+----------+
#
# ========= 2019-05-23 16:39:20 =========
# +--------------------+--------------------+------------+----------+
# |          book_title|       review_concat|review_score|prediction|
# +--------------------+--------------------+------------+----------+
# |The Rational Bibl...|Rational Bible I ...|           5|       0.0|
# +--------------------+--------------------+------------+----------+
#
# ========= 2019-05-23 16:45:40 =========
# +--------------------+--------------------+------------+----------+
# |          book_title|       review_concat|review_score|prediction|
# +--------------------+--------------------+------------+----------+
# |The Great Alone: ...|Powerful! A beaut...|           4|       1.0|
# +--------------------+--------------------+------------+----------+
#
# ========= 2019-05-23 16:46:40 =========
# +--------------------+--------------------+------------+----------+
# |          book_title|       review_concat|review_score|prediction|
# +--------------------+--------------------+------------+----------+
# |The Rational Bibl...|Rational Bible I ...|           5|       0.0|
# +--------------------+--------------------+------------+----------+

# %%
ssc_t.stop()
# Out:
# ----- Stopping... this may take a few seconds -----
